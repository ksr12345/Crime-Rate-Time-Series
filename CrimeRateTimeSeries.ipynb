# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\pujar\anaconda3\lib\site-packages (1.1.4)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: importlib-resources in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.25 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (0.31)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\pujar\anaconda3\lib\site-packages (from prophet) (1.1.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\pujar\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\pujar\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in c:\users\pujar\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2022.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\pujar\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\pujar\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\pujar\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
chicago_df_1 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv', error_bad_lines = False)
chicago_df_2 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv', error_bad_lines = False)
chicago_df_3 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv', error_bad_lines = False)
# Out:
# C:\Users\pujar\AppData\Local\Temp\ipykernel_9456\3620435975.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chicago_df_1 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv', error_bad_lines = False)
# Skipping line 533719: expected 23 fields, saw 24
#
# C:\Users\pujar\AppData\Local\Temp\ipykernel_9456\3620435975.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chicago_df_2 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv', error_bad_lines = False)
# Skipping line 1149094: expected 23 fields, saw 41
#
# C:\Users\pujar\AppData\Local\Temp\ipykernel_9456\3620435975.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chicago_df_3 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv', error_bad_lines = False)

# %%
chicago_df = pd.concat([chicago_df_1, chicago_df_2, chicago_df_3])

# %%
chicago_df.shape
# Out:
# (6017767, 23)

# %%
chicago_df.head()
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0           0  4673626    HM274058  04/02/2006 01:00:00 PM
# 1           1  4673627    HM202199  02/26/2006 01:40:48 PM
# 2           2  4673628    HM113861  01/08/2006 11:16:00 PM
# 3           4  4673629    HM274049  04/05/2006 06:45:00 PM
# 4           5  4673630    HM187120  02/17/2006 09:03:14 PM
#
#                  Block  IUCR   Primary Type                   Description  \
# 0    055XX N MANGO AVE  2825  OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1   065XX S RHODES AVE  2017      NARCOTICS            MANU/DELIVER:CRACK
# 2      013XX E 69TH ST  051A        ASSAULT           AGGRAVATED: HANDGUN
# 3  061XX W NEWPORT AVE  0460        BATTERY                        SIMPLE
# 4      037XX W 60TH ST  1811      NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False  ...  45.0            11.0        26
# 1             SIDEWALK    True  ...  20.0            42.0        18
# 2                OTHER   False  ...   5.0            69.0       04A
# 3            RESIDENCE   False  ...  38.0            17.0       08B
# 4                ALLEY    True  ...  13.0            65.0        18
#
#    X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 0     1136872.0     1936499.0  2006  04/15/2016 08:55:02 AM  41.981913
# 1     1181027.0     1861693.0  2006  04/15/2016 08:55:02 AM  41.775733
# 2     1186023.0     1859609.0  2006  04/15/2016 08:55:02 AM  41.769897
# 3     1134772.0     1922299.0  2006  04/15/2016 08:55:02 AM  41.942984
# 4     1152412.0     1864560.0  2006  04/15/2016 08:55:02 AM  41.784211
#
#    Longitude                       Location
# 0 -87.771996  (41.981912692, -87.771996382)
# 1 -87.611920  (41.775732538, -87.611919814)
# 2 -87.593671  (41.769897392, -87.593670899)
# 3 -87.780057  (41.942984005, -87.780056951)
# 4 -87.716745   (41.784210853, -87.71674491)
#
# [5 rows x 23 columns]

# %%
chicago_df.drop(['Unnamed: 0', 'Case Number', 'ID', 'IUCR', 'X Coordinate', 'Y Coordinate', 'Updated On', 'Year', 'FBI Code', 'Beat', 'Ward', 'Community Area', 'Location', 'District', 'Latitude', 'Longitude'], inplace = True, axis = 1)

# %%
chicago_df
# Out:
#                            Date                 Block     Primary Type  \
# 0        04/02/2006 01:00:00 PM     055XX N MANGO AVE    OTHER OFFENSE
# 1        02/26/2006 01:40:48 PM    065XX S RHODES AVE        NARCOTICS
# 2        01/08/2006 11:16:00 PM       013XX E 69TH ST          ASSAULT
# 3        04/05/2006 06:45:00 PM   061XX W NEWPORT AVE          BATTERY
# 4        02/17/2006 09:03:14 PM       037XX W 60TH ST        NARCOTICS
# ...                         ...                   ...              ...
# 1456709  05/03/2016 11:33:00 PM       026XX W 23RD PL          BATTERY
# 1456710  05/03/2016 11:30:00 PM   073XX S HARVARD AVE  CRIMINAL DAMAGE
# 1456711  05/03/2016 12:15:00 AM       024XX W 63RD ST          BATTERY
# 1456712  05/03/2016 09:07:00 PM  082XX S EXCHANGE AVE          BATTERY
# 1456713  05/03/2016 11:38:00 PM       001XX E 75TH ST    OTHER OFFENSE
#
#                           Description            Location Description  Arrest  \
# 0             HARASSMENT BY TELEPHONE                       RESIDENCE   False
# 1                  MANU/DELIVER:CRACK                        SIDEWALK    True
# 2                 AGGRAVATED: HANDGUN                           OTHER   False
# 3                              SIMPLE                       RESIDENCE   False
# 4        POSS: CANNABIS 30GMS OR LESS                           ALLEY    True
# ...                               ...                             ...     ...
# 1456709       DOMESTIC BATTERY SIMPLE                       APARTMENT    True
# 1456710                   TO PROPERTY                       APARTMENT    True
# 1456711           AGGRAVATED: HANDGUN                        SIDEWALK   False
# 1456712       DOMESTIC BATTERY SIMPLE                        SIDEWALK   False
# 1456713       OTHER WEAPONS VIOLATION  PARKING LOT/GARAGE(NON.RESID.)    True
#
#          Domestic
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1456709      True
# 1456710      True
# 1456711     False
# 1456712      True
# 1456713     False
#
# [6017767 rows x 7 columns]

# %%
chicago_df.Date = pd.to_datetime(chicago_df.Date, format = '%m/%d/%Y %I:%M:%S %p')

# %%
chicago_df.Date
# Out:
# 0         2006-04-02 13:00:00
# 1         2006-02-26 13:40:48
# 2         2006-01-08 23:16:00
# 3         2006-04-05 18:45:00
# 4         2006-02-17 21:03:14
#                   ...
# 1456709   2016-05-03 23:33:00
# 1456710   2016-05-03 23:30:00
# 1456711   2016-05-03 00:15:00
# 1456712   2016-05-03 21:07:00
# 1456713   2016-05-03 23:38:00
# Name: Date, Length: 6017767, dtype: datetime64[ns]

# %%
chicago_df.index = pd.DatetimeIndex(chicago_df.Date)

# %%
chicago_df['Primary Type'].value_counts()
# Out:
# THEFT                                1245111
# BATTERY                              1079178
# CRIMINAL DAMAGE                       702702
# NARCOTICS                             674831
# BURGLARY                              369056
# OTHER OFFENSE                         368169
# ASSAULT                               360244
# MOTOR VEHICLE THEFT                   271624
# ROBBERY                               229467
# DECEPTIVE PRACTICE                    225180
# CRIMINAL TRESPASS                     171596
# PROSTITUTION                           60735
# WEAPONS VIOLATION                      60335
# PUBLIC PEACE VIOLATION                 48403
# OFFENSE INVOLVING CHILDREN             40260
# CRIM SEXUAL ASSAULT                    22789
# SEX OFFENSE                            20172
# GAMBLING                               14755
# INTERFERENCE WITH PUBLIC OFFICER       14009
# LIQUOR LAW VIOLATION                   12129
# ARSON                                   9269
# HOMICIDE                                5879
# KIDNAPPING                              4734
# INTIMIDATION                            3324
# STALKING                                2866
# OBSCENITY                                422
# PUBLIC INDECENCY                         134
# OTHER NARCOTIC VIOLATION                 122
# NON-CRIMINAL                              96
# CONCEALED CARRY LICENSE VIOLATION         90
# NON - CRIMINAL                            38
# HUMAN TRAFFICKING                         28
# RITUALISM                                 16
# NON-CRIMINAL (SUBJECT SPECIFIED)           4
# Name: Primary Type, dtype: int64

# %%
order_data = chicago_df['Primary Type'].value_counts().iloc[:15].index

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y = 'Primary Type', data = chicago_df, order = order_data )
# Out:
# <Axes: xlabel='count', ylabel='Primary Type'>

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y = 'Location Description', data = chicago_df, order = chicago_df['Location Description'].value_counts().iloc[:15].index)
# Out:
# <Axes: xlabel='count', ylabel='Location Description'>

# %%
chicago_df.resample('Y').size()
# Out:
# Date
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: A-DEC, dtype: int64

# %%
plt.plot(chicago_df.resample('Y').size())
plt.title('Crime Count Per Year')
plt.xlabel('Years')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
plt.plot(chicago_df.resample('M').size())
plt.title('Crime Count Per Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
plt.plot(chicago_df.resample('Q').size())
plt.title('Crime Count Per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
chicago_prophet = chicago_df.resample('M').size().reset_index()

# %%
chicago_prophet
# Out:
#           Date      0
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet_df_final = chicago_prophet.rename(columns = {'Date': 'ds', 0 : 'y'})

# %%
chicago_prophet_df_final
# Out:
#             ds      y
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet_df_final['y'] = chicago_prophet_df_final['y'].astype(float)

# %%
chicago_prophet_df_final
# Out:
#             ds        y
# 0   2005-01-31  33983.0
# 1   2005-02-28  32042.0
# 2   2005-03-31  36970.0
# 3   2005-04-30  38963.0
# 4   2005-05-31  40572.0
# ..         ...      ...
# 140 2016-09-30  23235.0
# 141 2016-10-31  23314.0
# 142 2016-11-30  21140.0
# 143 2016-12-31  19580.0
# 144 2017-01-31  11357.0
#
# [145 rows x 2 columns]

# %%
m = Prophet()
m.fit(chicago_prophet_df_final)
# Out:
# 00:44:58 - cmdstanpy - INFO - Chain [1] start processing
# 00:44:59 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods = 365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  60455.329500  38314.650018  72022.056767  60455.329500
# 1   2005-02-28  60324.544550  34517.560400  67631.019205  60324.544550
# 2   2005-03-31  60179.746928  42369.750068  75386.576013  60179.746928
# 3   2005-04-30  60039.620196  44661.950882  77105.334815  60039.620196
# 4   2005-05-31  59894.822573  47478.804925  81953.072128  59894.822573
# ..         ...           ...           ...           ...           ...
# 505 2018-01-27   9656.534283 -10767.480548  21828.015041   9502.330125
# 506 2018-01-28   9643.198507 -11412.859785  22524.912086   9487.919545
# 507 2018-01-29   9629.862730 -10976.752893  22895.887546   9473.787774
# 508 2018-01-30   9616.526953 -10916.968226  21658.664341   9461.083728
# 509 2018-01-31   9603.191177 -11444.774729  22190.217965   9447.173416
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    60455.329500    -4782.927136          -4782.927136          -4782.927136
# 1    60324.544550    -9463.483428          -9463.483428          -9463.483428
# 2    60179.746928    -1246.764640          -1246.764640          -1246.764640
# 3    60039.620196     1111.429663           1111.429663           1111.429663
# 4    59894.822573     5386.559935           5386.559935           5386.559935
# ..            ...             ...                   ...                   ...
# 505   9820.744297    -4094.868857          -4094.868857          -4094.868857
# 506   9808.440066    -4237.127815          -4237.127815          -4237.127815
# 507   9796.135835    -4391.658528          -4391.658528          -4391.658528
# 508   9783.831604    -4558.195286          -4558.195286          -4558.195286
# 509   9771.527373    -4736.524649          -4736.524649          -4736.524649
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -4782.927136  -4782.927136  -4782.927136                   0.0
# 1   -9463.483428  -9463.483428  -9463.483428                   0.0
# 2   -1246.764640  -1246.764640  -1246.764640                   0.0
# 3    1111.429663   1111.429663   1111.429663                   0.0
# 4    5386.559935   5386.559935   5386.559935                   0.0
# ..           ...           ...           ...                   ...
# 505 -4094.868857  -4094.868857  -4094.868857                   0.0
# 506 -4237.127815  -4237.127815  -4237.127815                   0.0
# 507 -4391.658528  -4391.658528  -4391.658528                   0.0
# 508 -4558.195286  -4558.195286  -4558.195286                   0.0
# 509 -4736.524649  -4736.524649  -4736.524649                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  55672.402364
# 1                           0.0                         0.0  50861.061122
# 2                           0.0                         0.0  58932.982288
# 3                           0.0                         0.0  61151.049859
# 4                           0.0                         0.0  65281.382508
# ..                          ...                         ...           ...
# 505                         0.0                         0.0   5561.665426
# 506                         0.0                         0.0   5406.070692
# 507                         0.0                         0.0   5238.204202
# 508                         0.0                         0.0   5058.331667
# 509                         0.0                         0.0   4866.666528
#
# [510 rows x 16 columns]

# %%
figure = m.plot(forecast, xlabel = 'Date', ylabel = 'Crime Rate')

# %%
figure = m.plot_components(forecast)
